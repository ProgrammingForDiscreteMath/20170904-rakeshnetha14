# %%
G=[]
f(x)=0
for i in range(10):
    f(x)=f(x)+(x^i/(factorial(i)))
    G = G+[f.plot(xmin=-2, xmax=2, rgbcolor = (1-i/10.0, i/10.0, 0),legend_label='series upto n=%d'%i)]
    a=animate(G)
    
a.show()
# Out:
# Animation with 10 frames
